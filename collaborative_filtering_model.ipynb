# %%
# Load spotify playlists data
import random
import pandas as pd

playlists_df = pd.read_csv(
    "data/spotify_playlists.csv", 
    on_bad_lines='skip',
    quoting=1,  # QUOTE_ALL
    encoding='utf-8',
    encoding_errors='ignore',
    nrows=500000
)
print("Playlists data loaded:")
print(f"Total rows: {len(playlists_df)}")
print(f"Column names: {playlists_df.columns.tolist()}")
print(f"\nFirst few rows:\n{playlists_df.head()}")

# Strip quotes from column names if present
playlists_df.columns = playlists_df.columns.str.strip().str.replace('"', '')
print(f"\nCleaned column names: {playlists_df.columns.tolist()}")

if 'playlistname' in playlists_df.columns:
    print(f"\nUnique playlists: {playlists_df['playlistname'].nunique()}")
    print(f"\nSample playlists:\n{playlists_df['playlistname'].value_counts().head()}")
else:
    print("\nNote: 'playlistname' column not found. Check column names above.")
# Out:
# Playlists data loaded:
# Total rows: 500000
# Column names: ['user_id', ' "artistname"', ' "trackname"', ' "playlistname"']
#
# First few rows:
#                             user_id                      "artistname"  \
# 0  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2  9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3  9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4  9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
#
#                                          "trackname"  "playlistname"
# 0               (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1  (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                   7 Years Too Late  HARD ROCK 2010
# 3                              Accidents Will Happen  HARD ROCK 2010
# 4                                             Alison  HARD ROCK 2010
#
# Cleaned column names: ['user_id', 'artistname', 'trackname', 'playlistname']
#
# Unique playlists: 8808
#
# Sample playlists:
# playlistname
# Starred               46773
# Everything at once     7892
# Spotify Library        7645
# Liked from Radio       7208
# Strane                 6825
# Name: count, dtype: int64

# %%
import unicodedata, re

def normalize_text(s):
    if pd.isna(s):
        return ''
    s = str(s).lower().strip()
    s = unicodedata.normalize('NFKD', s)
    s = re.sub(r'\s+', ' ', s)
    # remove common parenthetical tags like (remastered), [live], - remaster
    s = re.sub(r'\s*\([^)]*\)\s*', ' ', s)
    s = re.sub(r'\s*\[[^]]*\]\s*', ' ', s)
    s = re.sub(r'- remaster(ed)?', '', s)
    s = re.sub(r"'", '', s)
    s = s.strip()
    return s

# Add normalized columns
playlists_df['t_norm'] = playlists_df['trackname'].astype(str).map(normalize_text)
playlists_df['a_norm'] = playlists_df['artistname'].astype(str).map(normalize_text)

print('Added normalized columns to playlists_df')
# Out:
# Added normalized columns to playlists_df

# %%
import pandas as pd
recommendationInfo_df = pd.read_csv('data/recommendation_info.csv', encoding='utf-8', encoding_errors='ignore', on_bad_lines='skip')
recommendationInfo_df.columns = recommendationInfo_df.columns.str.strip().str.replace('"', '')
print('Loaded recommendationInfo_df')

# Add normalized columns to recommendationInfo_df
recommendationInfo_df['t_norm'] = recommendationInfo_df['track_name'].astype(str).map(normalize_text)
recommendationInfo_df['a_norm'] = recommendationInfo_df['track_artist'].astype(str).map(normalize_text)

# Build lookup mapping from (t_norm,a_norm) to dataset index
rec_lookup = {}
for idx, row in recommendationInfo_df.iterrows():
    key = (row.t_norm, row.a_norm)
    if key not in rec_lookup:
        rec_lookup[key] = idx

print(f'Recommendation lookup size: {len(rec_lookup)} unique songs (from {len(recommendationInfo_df)} total entries)')
# Out:
# Loaded recommendationInfo_df
# Recommendation lookup size: 25942 unique songs (from 32828 total entries)
# Recommendation lookup size: 25942 unique songs (from 32828 total entries)

# %%
# Map playlist rows to dataset indices
def map_row_to_idx(row):
    return rec_lookup.get((row['t_norm'], row['a_norm']))

playlists_df['dataset_idx'] = playlists_df.apply(map_row_to_idx, axis=1)

# playlist statistics
stats = playlists_df.groupby('playlistname').agg(\
    total_count=('trackname', 'count'),
    matched_count=('dataset_idx', lambda s: s.notnull().sum())\
).reset_index()

print('Playlist stats sample:')
print(stats.sort_values('matched_count', ascending=False).head())
# Out:
# Playlist stats sample:
#                playlistname  total_count  matched_count
# 6452                Starred        46772           6950
# 4090       Liked from Radio         7208           1305
# 2399     Everything at once         7892            762
# 2498  Favoritas de la radio         2237            723
# 6508                 Strane         6825            532

# %%
# Pick 20 playlists for CF model training
min_size = 20
max_size = 300
min_matched = 30
candidates = stats[(stats['total_count'].between(min_size, max_size)) & (stats['matched_count'] >= min_matched)].copy()
print(f'Found {len(candidates)} candidate playlists between {min_size}-{max_size} tracks with at least {min_matched} matched songs')

chosen = candidates.sort_values('matched_count', ascending=False).head(20)['playlistname'].tolist()
print('Chosen playlists for evaluation (examples):')
print(chosen)
# Out:
# Found 212 candidate playlists between 20-300 tracks with at least 30 matched songs
# Chosen playlists for evaluation (examples):
# ['Birgit Party', 'ZLX', "80's (full)", 'Afternoon Delight', 'hippity hoppity', 'New Year 2011/2012', 'random', 'Mobil', 'Selections', 'high school days', 'ailygames', 'rock', 'Pump Up the Jam', 'Tiririri tururu lerelere', 'partypants', 'EDM | House | Tomorrowland 2015 | Latest house | summerburst 2015 | kygo | avicii | Axwell ingrosso | Magaluf 2015', 'Scelto dalla radio', 'Soundtrack de vida', 'Childhood memories', 'Norris']

# %%
# Build playlist x item CSR matrix, only include playlists that have at least one matched row
from scipy.sparse import csr_matrix

playlist_names = playlists_df['playlistname'].astype(str).unique().tolist()
playlist_to_id = {p:i for i,p in enumerate(playlist_names)}
item_count = len(recommendationInfo_df)
rows, cols, vals = [], [], []
for _, r in playlists_df.dropna(subset=['dataset_idx']).iterrows():
    pid = playlist_to_id[str(r['playlistname'])]
    item_idx = int(r['dataset_idx'])
    rows.append(pid); cols.append(item_idx); vals.append(1)

user_item = csr_matrix((vals, (rows, cols)), shape=(len(playlist_to_id), item_count))
print('Built user_item matrix with shape:', user_item.shape)

id_to_playlist = {v:k for k,v in playlist_to_id.items()}
# Out:
# Built user_item matrix with shape: (8809, 32828)

# %%
# collaborative filtering using SVD
from sklearn.decomposition import TruncatedSVD
import numpy as np

print('Training collaborative filtering model using SVD...')
print(f'Input matrix shape: {user_item.shape}')

n_factors = 128
svd = TruncatedSVD(n_components=n_factors, random_state=42)

# Fit on the user-item matrix and get item factors
playlist_factors = svd.fit_transform(user_item)
item_factors = svd.components_.T  # (n_items, n_factors)

print(f'SVD trained')
print(f'Item factors shape: {item_factors.shape}')
print(f'Playlist factors shape: {playlist_factors.shape}')
print(f'Explained variance ratio: {svd.explained_variance_ratio_.sum():.4f}')
# Out:
# Training collaborative filtering model using SVD...
# Input matrix shape: (8809, 32828)
# SVD trained
# Item factors shape: (32828, 128)
# Playlist factors shape: (8809, 128)
# Explained variance ratio: 0.7214

# %%
# Collaborative recommendation wrapper using trained item_factors
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def recommend_collaborative(seed_song_tuples, n_recs=50):
    if item_factors is None:
        return 'CF model not trained; item_factors is None'
    seed_idxs = []
    for title, artist in seed_song_tuples:
        key = (normalize_text(title), normalize_text(artist))
        idx = rec_lookup.get(key)
        if idx is not None:
            seed_idxs.append(idx)
    if not seed_idxs:
        return 'No valid seeds found in recommendation dataset'
    query = item_factors[seed_idxs].mean(axis=0).reshape(1,-1)
    sims = cosine_similarity(query, item_factors).flatten()
    ranking = np.argsort(-sims)
    recs = [r for r in ranking if r not in seed_idxs][:n_recs]
    return recommendationInfo_df.iloc[recs].reset_index(drop=True)

print('recommend_collaborative defined')
# Out:
# recommend_collaborative defined

# %%
# adjusted evaluate_playlist function from KNN model for CF model
def evaluate_playlist(playlist_name, n_seed=5, n_recs=10):
    """
    Takes a playlist name, randomly selects n_seed songs from it that exist in our dataset,
    gets recommendations, and checks if any recommendations are from the original playlist.
    
    Parameters:
    - playlist_name: name of playlist in spotify_playlists.csv
    - n_seed: number of songs to use as input (default 5)
    - n_recs: number of recommendations to generate (default 10)
    
    Returns:
    - Dictionary with evaluation results
    """
    # Get all songs from the specified playlist
    playlist_songs = playlists_df[playlists_df['playlistname'] == playlist_name].copy()
    
    if len(playlist_songs) == 0:
        return {"error": f"Playlist '{playlist_name}' not found"}
    
    # Build output in memory
    output = []
    output.append(f"\n{'='*60}")
    output.append(f"Evaluating Playlist: {playlist_name}")
    output.append(f"{'='*60}")
    output.append(f"Total songs in playlist: {len(playlist_songs)}")
    
    # Find which playlist songs exist in our recommendation dataset (using pre-mapped dataset_idx)
    matched_songs = []
    for idx, row in playlist_songs.iterrows():
        if pd.notna(row.get('dataset_idx')):
            matched_songs.append({
                'track': row['trackname'],
                'artist': row['artistname'],
                'dataset_idx': int(row['dataset_idx'])
            })
    
    output.append(f"Songs found in our dataset: {len(matched_songs)}/{len(playlist_songs)}")
    
    if len(matched_songs) < n_seed:
        return {
            "error": f"Not enough songs in dataset. Found {len(matched_songs)}, need at least {n_seed}",
            "matched_count": len(matched_songs),
            "total_count": len(playlist_songs)
        }
    
    # Randomly select n_seed songs as input
    random.seed(42)  # For reproducibility
    seed_songs = random.sample(matched_songs, n_seed)
    remaining_songs = [s for s in matched_songs if s not in seed_songs]
    
    output.append(f"\n--- Input Songs (randomly selected {n_seed}) ---")
    for i, song in enumerate(seed_songs, 1):
        output.append(f"{i}. {song['track']} — {song['artist']}")
    
    # Get recommendations using collaborative filtering
    seed_list = [(song['track'], song['artist']) for song in seed_songs]
    recs_df = recommend_collaborative(seed_list, n_recs=n_recs)
    
    # Check if recommend_collaborative returned an error
    if isinstance(recs_df, str):
        return {"error": recs_df}
    
    remaining_indices = {s['dataset_idx'] for s in remaining_songs}
    hits = []
    
    output.append(f"\n--- Recommendations ({len(recs_df)} songs) ---")
    
    # Get the original indices from recommendationInfo_df
    for i in range(len(recs_df)):
        row = recs_df.iloc[i]
        track = row['track_name']
        artist = row['track_artist']
        
        # Find the original index in recommendationInfo_df
        mask = (
            recommendationInfo_df["track_name"].str.lower().str.strip() == track.lower().strip()
        ) & (
            recommendationInfo_df["track_artist"].str.lower().str.strip() == artist.lower().strip()
        )
        
        if mask.sum() > 0:
            original_idx = recommendationInfo_df[mask].index[0]
            in_playlist = "✓ IN PLAYLIST" if original_idx in remaining_indices else ""
            output.append(f"{i+1}. {track} — {artist} {in_playlist}")
            
            if original_idx in remaining_indices:
                hits.append({'track': track, 'artist': artist, 'rank': i+1})
        else:
            output.append(f"{i+1}. {track} — {artist}")
    
    # Calculate metrics
    hit_rate = 1 if len(hits) > 0 else 0
    precision = len(hits) / n_recs if n_recs > 0 else 0
    recall = len(hits) / len(remaining_songs) if len(remaining_songs) > 0 else 0
    
    output.append(f"\n--- Evaluation Results ---")
    output.append(f"Songs in playlist (in dataset): {len(matched_songs)}")
    output.append(f"Used as input: {n_seed}")
    output.append(f"Held-out (ground truth): {len(remaining_songs)}")
    output.append(f"Recommendations generated: {len(recs_df)}")
    output.append(f"Hits (songs from playlist recommended): {len(hits)}")
    output.append(f"Hit Rate (at least 1 hit): {hit_rate}")
    output.append(f"Precision@{n_recs}: {precision:.4f}")
    output.append(f"Recall@{n_recs}: {recall:.4f}")
    
    if hits:
        output.append(f"\nHit songs (from original playlist):")
        for hit in hits:
            output.append(f"  - Rank {hit['rank']}: {hit['track']} — {hit['artist']}")
    
    # Print everything at once
    print('\n'.join(output))
    
    return {
        'playlist_name': playlist_name,
        'total_in_playlist': len(playlist_songs),
        'matched_in_dataset': len(matched_songs),
        'seed_count': n_seed,
        'held_out_count': len(remaining_songs),
        'n_recs': n_recs,
        'hits': len(hits),
        'hit_rate': hit_rate,
        'precision': precision,
        'recall': recall,
        'hit_songs': hits
    }

# %%
# Quick evaluation helper: run evaluate_playlist on chosen playlists and summarize
def eval_playlists(names, n_seed=10, n_recs=50):
    results = []
    for name in names:
        try:
            print('Evaluating', name)
            res = evaluate_playlist(name, n_seed=n_seed, n_recs=n_recs)
            results.append(res)
        except Exception as e:
            print('Error evaluating', name, e)
    return results

# Example: evaluate the chosen playlists if available
try:
    example_names = chosen
    res = eval_playlists(example_names, n_seed=10, n_recs=50)
    import pandas as pd
    df_res = pd.DataFrame(res)
    print('Mean precision:', df_res['precision'].mean())
except NameError:
    print('No chosen playlists defined yet; run the selection cell first')
# Out:
# Evaluating Birgit Party
#
# ============================================================
# Evaluating Playlist: Birgit Party
# ============================================================
# Total songs in playlist: 290
# Songs found in our dataset: 155/290
#
# --- Input Songs (randomly selected 10) ---
# 1. Carry on Wayward Son — Kansas
# 2. Always On My Mind — Pet Shop Boys
# 25. White Room — Cream
# 26. No More Mr. Nice Guy - Remastered Version — Alice Cooper
# 27. Evil Woman — Electric Light Orchestra
# 28. Caught Up In You — 38 Special ✓ IN PLAYLIST
# 29. Fool in the Rain — Led Zeppelin ✓ IN PLAYLIST
# 30. Good Times Roll — The Cars ✓ IN PLAYLIST
# 31. Walk Away — James Gang ✓ IN PLAYLIST
# 32. Pride and Joy — Stevie Ray Vaughan
# 33. You Really Got Me — Van Halen
# 34. Breathe (In the Air) — Pink Floyd
# 35. The Stroke - Remastered — Billy Squier
# 36. Sweet Emotion — Aerosmith
# 37. Take Me In Your Arms — Lil Suzy
# 38. Change On Me — Cynthia
# 39. Point of No Return — Exposé
# 40. Show Me (The Nest Mix) — The Cover Girls
# 41. Love Letter — Giggles
# 42. Take It While It's Hot — Sweet Sensation
# 43. Summertime, Summertime — Nocera
# 44. I'll Be All You'll Ever Need — Trinere
# 45. Where Are You Tonight — Coro
# 46. When I Hear Music — Debbie Deb
# 47. Please Don't Go (Freestyle Dance Usa Mix) — Nayobe
# 48. I Want You — Shana
# 49. A Day In My Life (Without You) — Lisette Melendez
# 50. Exposed To Love — Exposé
#
# --- Evaluation Results ---
# Songs in playlist (in dataset): 133
# Used as input: 10
# Held-out (ground truth): 123
# Recommendations generated: 50
# Hits (songs from playlist recommended): 14
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.2800
# Recall@50: 0.1138
#
# Hit songs (from original playlist):
#   - Rank 1: Show Me The Way - Live — Peter Frampton
#   - Rank 5: Turn! Turn! Turn! (To Everything There Is a Season) — The Byrds
#   - Rank 6: Whipping Post — The Allman Brothers Band
#   - Rank 8: Werewolves of London — Warren Zevon
#   - Rank 10: Eminence Front — The Who
#   - Rank 11: Smokin' — Boston
#   - Rank 17: Comfortably Numb - 2011 Remastered Version — Pink Floyd
#   - Rank 19: Lonely Is The Night — Billy Squier
#   - Rank 20: Evil Ways — Santana
#   - Rank 24: Another Brick In The Wall, Pt. 2 - 2011 Remastered Version — Pink Floyd
#   - Rank 28: Caught Up In You — 38 Special
#   - Rank 29: Fool in the Rain — Led Zeppelin
#   - Rank 30: Good Times Roll — The Cars
#   - Rank 31: Walk Away — James Gang
# Evaluating 80's (full)
#
# ============================================================
# Evaluating Playlist: 80's (full)
# ============================================================
# Total songs in playlist: 275
# Songs found in our dataset: 118/275
#
# --- Input Songs (randomly selected 10) ---
# 1. Sister Christian — Night Ranger
# 2. Broken Wings — Mr. Mister
# 3. 99 Luftballons — Nena
# 4. Town Called Malice — The Jam
# 5. Hurts So Good — John Mellencamp
# 6. Here I Go Again - 20th Anniversary Remaster — Whitesnake
# 7. Glory Days — Bruce Springsteen
# 8. Dancing in the Dark — Bruce Springsteen
# 9. Breaking the Law — Judas Priest
# 10. Take Me Home Tonight — Eddie Money
#
# --- Recommendations (50 songs) ---
# 1. Amanda — Boston ✓ IN PLAYLIST
# 2. Escapade — Janet Jackson ✓ IN PLAYLIST
# 3. Miss You Much — Janet Jackson
# 4. Would I Lie to You? - Remastered Version — Eurythmics ✓ IN PLAYLIST
# 5. Save It For Later — The English Beat ✓ IN PLAYLIST
# 6. New Sensation — INXS ✓ IN PLAYLIST
# 26. Right Thurr — Chingy
# 27. One, Two Step — Ciara
# 28. Grind with Me — Pretty Ricky
# 29. Candy Shop — 50 Cent
# 30. I'm a Thug — Trick Daddy ✓ IN PLAYLIST
# 31. Numb Numb — Juvenile
# 32. Enemy Turf — Juvenile
# 33. Fuckin With Me — Juvenile
# 34. One Call Away — Chingy
# 35. Where the Party At (feat. Nelly) — Jagged Edge
# 36. Let Me Blow Ya Mind — Eve
# 37. Always On Time — Ja Rule
# 38. Party Up — DMX
# 39. When I Grow Up — The Pussycat Dolls ✓ IN PLAYLIST
# 40. Jealous — Nick Jonas ✓ IN PLAYLIST
# 41. Whatta Man — Salt-N-Pepa ✓ IN PLAYLIST
# 42. Raise Up — Petey Pablo ✓ IN PLAYLIST
# 43. Feel so Good — Mase ✓ IN PLAYLIST
# 44. Don't You (Forget About Me) — Simple Minds
# 45. All Out of Love — Air Supply
# 46. Holidae In — Chingy ✓ IN PLAYLIST
# 47. Back That Azz Up — Juvenile
# 48. What's Your Fantasy (Featuring Shawna) — Ludacris
# 49. Come & Get It — Selena Gomez
# 50. Rosa Parks — OutKast
#
# --- Evaluation Results ---
# Songs in playlist (in dataset): 116
# Used as input: 10
# Held-out (ground truth): 106
# Recommendations generated: 50
# Hits (songs from playlist recommended): 20
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.4000
# Recall@50: 0.1887
#
# Hit songs (from original playlist):
#   - Rank 1: Rock Wit U (Awww Baby) — Ashanti
#   - Rank 2: Who's That Girl? — Eve
#   - Rank 3: Splash Waterfalls — Ludacris
#   - Rank 4: Ride Wit Me - Album Version (Edited) — Nelly
#   - Rank 5: Down A** B**ch — Ja Rule
#   - Rank 6: Take It to da House — Trick Daddy
#   - Rank 8: In Those Jeans — Ginuwine
#   - Rank 9: Overnight Celebrity — Twista
#   - Rank 11: Bartender (feat. Akon) — T-Pain
#   - Rank 18: Straight Up — Paula Abdul
#   - Rank 20: Tipsy - Radio Mix — J-Kwon
#   - Rank 22: I Need a Girl (Pt. One) (feat. Usher & Loon) — Diddy
#   - Rank 24: Slow Motion — Juvenile
#   - Rank 30: I'm a Thug — Trick Daddy
#   - Rank 39: When I Grow Up — The Pussycat Dolls
#   - Rank 40: Jealous — Nick Jonas
#   - Rank 41: Whatta Man — Salt-N-Pepa
#   - Rank 42: Raise Up — Petey Pablo
#   - Rank 43: Feel so Good — Mase
#   - Rank 46: Holidae In — Chingy
# Evaluating hippity hoppity
#
# ============================================================
# Evaluating Playlist: hippity hoppity
# ============================================================
# Total songs in playlist: 285
# Songs found in our dataset: 100/285
#
# --- Input Songs (randomly selected 10) ---
# 1. So Fresh, So Clean — OutKast
# 2. Bring Da Ruckus — Wu-Tang Clan
# 3. A Milli — Lil Wayne
# 4. The World Is Yours — Nas
# 5. Hip Hop — Dead Prez
# 6. Going Back To Cali — The Notorious B.I.G.
# 7. Gangsta's Paradise — Coolio
# 8. Can't Tell Me Nothing — Kanye West
# 9. Bitch, Don’t Kill My Vibe — Kendrick Lamar
# 10. Straight Outta Compton — N.W.A.
#
# --- Recommendations (50 songs) ---
# 1. U.O.E.N.O. (feat. Rick Ross, Future) — Rocko ✓ IN PLAYLIST
#
# --- Evaluation Results ---
# Songs in playlist (in dataset): 92
# Used as input: 10
# Held-out (ground truth): 82
# Recommendations generated: 50
# Hits (songs from playlist recommended): 10
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.2000
# Recall@50: 0.1220
#
# Hit songs (from original playlist):
#   - Rank 4: Yee - Radio Edit — Deorro
#   - Rank 5: Get Low — Dillon Francis
#   - Rank 6: Hey Mister — Tujamo
#   - Rank 18: Strange Clouds - feat. Lil Wayne — B.o.B
#   - Rank 22: Good Time — Owl City
#   - Rank 30: Get Loose — Showtek
#   - Rank 32: Started From the Bottom — Drake
#   - Rank 34: Not Fair — Lily Allen
#   - Rank 38: Harlem Shake — Baauer
#   - Rank 40: Faded — Tyga
# Evaluating Selections
#
# ============================================================
# Evaluating Playlist: Selections
# ============================================================
# Total songs in playlist: 265
# Songs found in our dataset: 89/265
#
# --- Input Songs (randomly selected 10) ---
# 1. Use Somebody — Kings Of Leon
# 2. Cold As Ice (2008 Remastered LP Version) — Foreigner
# 3. All Star — Smash Mouth
# 4. Just Like Heaven — The Cure
# 5. Hunger Strike — Temple Of The Dog
# 6. Go Your Own Way — Fleetwood Mac
# 7. Crocodile Rock — Elton John
# 8. China Grove — The Doobie Brothers
# 9. You Can't Always Get What You Want — The Rolling Stones
# 10. Stricken — Disturbed
#
# --- Recommendations (50 songs) ---
# 1. Megalomaniac — Incubus ✓ IN PLAYLIST
# 2. Sympathy For The Devil — The Rolling Stones
# 3. Fooled Around And Fell In Love — Elvin Bishop ✓ IN PLAYLIST
# 4. Gimme Shelter — The Rolling Stones
# 5. Wild Horses — The Rolling Stones
# 6. Beast Of Burden - Remastered — The Rolling Stones
# 7. Snuff — Slipknot ✓ IN PLAYLIST
# 8. Honky Tonk Women — The Rolling Stones
# 9. Fly Like An Eagle — Steve Miller Band ✓ IN PLAYLIST
# 10. China Grove — The Doobie Brothers
# 11. Death On Two Legs (Dedicated To...) - Remastered 2011 — Queen
# 12. Honky Tonk Women - Mono Version — The Rolling Stones
# 13. Under My Thumb — The Rolling Stones
# 14. Start Me Up - Remastered — The Rolling Stones
# 15. Tumbling Dice — The Rolling Stones
# 16. Tribute — Tenacious D ✓ IN PLAYLIST
# 17. Spoonman — Soundgarden ✓ IN PLAYLIST
# 18. YYZ — Rush
# 19. Scenes from an Italian Restaurant — Billy Joel ✓ IN PLAYLIST
# 20. Miss Murder — AFI ✓ IN PLAYLIST
# 21. Angie — The Rolling Stones
# 22. Brown Sugar — The Rolling Stones
# 23. Ramblin' Man — The Allman Brothers Band
# 24. Rhiannon — Fleetwood Mac ✓ IN PLAYLIST
# 25. Let's Spend The Night Together - Stereo Version — The Rolling Stones
# 26. The Only — Static-X ✓ IN PLAYLIST
# 27. These Eyes - Remastered — The Guess Who
# 28. 25 or 6 to 4 — Chicago ✓ IN PLAYLIST
# 29. (I Can't Get No) Satisfaction - Mono Version — The Rolling Stones
# 30. Magic — Pilot ✓ IN PLAYLIST
# 31. Say It Ain't So — Weezer
# 32. Pinball Wizard - Original Album Version — The Who ✓ IN PLAYLIST
# 33. Hold On Loosely — 38 Special ✓ IN PLAYLIST
# 34. Aqualung — Jethro Tull ✓ IN PLAYLIST
# 35. Absolutely (Story of a Girl) - Radio Mix — Nine Days ✓ IN PLAYLIST
# 36. Jumpin' Jack Flash — The Rolling Stones
# 37. Layla — Derek & The Dominos
# 38. Who Can It Be Now? — Men At Work
# 39. Eres — Café Tacvba ✓ IN PLAYLIST
# 40. Esperanza — Control Machete
# 41. Ileso — Control Machete
# 42. Asi Son Mis Dias — Control Machete
# 43. Roll with the Changes — REO Speedwagon ✓ IN PLAYLIST
# 44. Paint It Black — The Rolling Stones
# 45. Can't You Hear Me Knocking - Remastered — The Rolling Stones
# 46. Black Hole Sun — Soundgarden
# 47. The Look — Roxette ✓ IN PLAYLIST
# 48. Peace of Mind — Boston
# 49. The Power Of Love — Huey Lewis & The News ✓ IN PLAYLIST
# 50. Foreplay / Long Time — Boston
#
# --- Evaluation Results ---
# Songs in playlist (in dataset): 89
# Used as input: 10
# Held-out (ground truth): 79
# Recommendations generated: 50
# Hits (songs from playlist recommended): 20
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.4000
# Recall@50: 0.2532
#
# Hit songs (from original playlist):
#   - Rank 1: Megalomaniac — Incubus
#   - Rank 3: Fooled Around And Fell In Love — Elvin Bishop
#   - Rank 7: Snuff — Slipknot
#   - Rank 9: Fly Like An Eagle — Steve Miller Band
#   - Rank 16: Tribute — Tenacious D
#   - Rank 17: Spoonman — Soundgarden
#   - Rank 19: Scenes from an Italian Restaurant — Billy Joel
#   - Rank 20: Miss Murder — AFI
#   - Rank 24: Rhiannon — Fleetwood Mac
#   - Rank 26: The Only — Static-X
#   - Rank 28: 25 or 6 to 4 — Chicago
#   - Rank 30: Magic — Pilot
#   - Rank 32: Pinball Wizard - Original Album Version — The Who
#   - Rank 33: Hold On Loosely — 38 Special
#   - Rank 34: Aqualung — Jethro Tull
#   - Rank 35: Absolutely (Story of a Girl) - Radio Mix — Nine Days
#   - Rank 39: Eres — Café Tacvba
#   - Rank 43: Roll with the Changes — REO Speedwagon
#   - Rank 47: The Look — Roxette
#   - Rank 49: The Power Of Love — Huey Lewis & The News
# Evaluating high school days
#
# ============================================================
# Evaluating Playlist: high school days
# ============================================================
# Total songs in playlist: 210
# Songs found in our dataset: 83/210
#
# --- Input Songs (randomly selected 10) ---
# 1. Year 3000 — Jonas Brothers
# 2. Don't Cha — The Pussycat Dolls
# 3. All The Small Things — blink-182
# 4. Kiss Me Thru The Phone — Soulja Boy
# 5. Ignition - Remix — R. Kelly
# 6. Hot N Cold — Katy Perry
# 7. Fireflies — Owl City
# 8. DONTTRUSTME — 3OH!3
# 9. Super Bass — Nicki Minaj
# 10. Crush — David Archuleta
#
# --- Recommendations (50 songs) ---
# 1. Lemonade — Gucci Mane ✓ IN PLAYLIST
# 2. Suga Suga — Baby Bash
# 3. Outside Looking In — Jordan Pruitt ✓ IN PLAYLIST
# 4. S.O.S. — Jonas Brothers ✓ IN PLAYLIST
# 5. Burnin' Up — Jonas Brothers ✓ IN PLAYLIST
# 6. Potential Breakup Song — Aly & AJ ✓ IN PLAYLIST
# 7. I Kissed A Girl — Katy Perry
# 8. No Air (feat. Chris Brown) — Jordin Sparks ✓ IN PLAYLIST
# 34. Hey Now - Arty Remix — London Grammar
# 35. Impossible — James Arthur ✓ IN PLAYLIST
# 36. Wild Out (feat. Waka Flocka Flame & Paige) — Borgore
# 37. Cut Your Teeth - Kygo Remix — Kyla La Grange
# 38. Summertime Sadness (Lana Del Rey Vs. Cedric Gervais) - Cedric Gervais Remix — Lana Del Rey
# 39. Old Thing Back (feat. Ja Rule and Ralph Tresvant) — Matoma
# 40. Greatest DJ - Radio Edit — twoloud
# 41. Dear Life - Original Mix — Dannic
# 42. You Know You Like It — DJ Snake
# 43. Weapon - EDX's Acapulco At Night Remix — CAZZETTE
# 44. Damaged - Radio Edit — Adrian Lux
# 45. Back to Earth (feat. Fall Out Boy) — Steve Aoki
# 46. Let Me Love You (Until You Learn To Love Yourself) — Ne-Yo ✓ IN PLAYLIST
# 47. Glad You Came — The Wanted
# 48. Set Me on Fire — Flyleaf
# 49. You're Gonna Love Again — NERVO
# 50. Say Something — A Great Big World
#
# --- Evaluation Results ---
# Songs in playlist (in dataset): 79
# Used as input: 10
# Held-out (ground truth): 69
# Recommendations generated: 50
# Hits (songs from playlist recommended): 9
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.1800
# Recall@50: 0.1304
#
# Hit songs (from original playlist):
#   - Rank 1: Delirious (Boneless) (feat. Kid Ink) — Steve Aoki
#   - Rank 4: I Am the Best (내가 제일 잘 나가) — 2NE1
#   - Rank 5: Wing$ — Macklemore & Ryan Lewis
#   - Rank 6: Man Down — Rihanna
#   - Rank 8: Warriors — Imagine Dragons
#   - Rank 15: Because Of You — Ne-Yo
#   - Rank 33: You Make Me — Avicii
#   - Rank 35: Impossible — James Arthur
#   - Rank 46: Let Me Love You (Until You Learn To Love Yourself) — Ne-Yo
# Evaluating rock
#
# ============================================================
# Evaluating Playlist: rock
# ============================================================
# Total songs in playlist: 156
# Songs found in our dataset: 79/156
#
# --- Input Songs (randomly selected 10) ---
# 1. Wake Me Up When September Ends — Green Day
# 2. Sweet Home Alabama — Lynyrd Skynyrd
# 3. Hallowed Be Thy Name - 1998 Remastered Version — Iron Maiden
# 4. Don't Stop Believin' — Journey
# 5. Come As You Are — Nirvana
# 6. Last Nite — The Strokes
# 7. To Be With You — Mr. Big
# 8. The Kill (Bury Me) — Thirty Seconds To Mars
# 9. Lightning Crashes — Live
# 10. One Step Closer — Linkin Park
#
# --- Recommendations (50 songs) ---
# 1. Guitar Man — Bread ✓ IN PLAYLIST
# 2. 21 Guns — Green Day ✓ IN PLAYLIST
# 3. Piece of My Heart — Big Brother & The Holding Company
# 4. So Far Away — Staind ✓ IN PLAYLIST
# 5. Basket Case — Green Day
# 6. Lying from You — Linkin Park ✓ IN PLAYLIST
# 7. Prayer Of The Refugee — Rise Against ✓ IN PLAYLIST
# 8. Sweet Home Alabama — Lynyrd Skynyrd
# 9. 18 and Life — Skid Row
# 10. In the End — Linkin Park
# 11. American Idiot — Green Day
# 12. One Last Breath — Creed ✓ IN PLAYLIST
# 13. Higher — Creed ✓ IN PLAYLIST
# 14. Breaking the Habit — Linkin Park ✓ IN PLAYLIST
# 15. Iron Man — Black Sabbath
# 16. Hero — Skillet ✓ IN PLAYLIST
# 17. Alone Again — Dokken
# 18. Forever — KISS
# 19. Wait — White Lion
# 20. Up All Night — Slaughter
# 21. Comatose — Skillet ✓ IN PLAYLIST
# 22. Jump — Van Halen
# 23. High Enough — Damn Yankees
# 24. Uncle Tom's Cabin — Warrant
# 25. Live Wire — Mötley Crüe
# 26. Let It Go - English Version — Idina Menzel
# 27. Dust — M|O|O|N
# 28. The Devil in I — Slipknot
# 29. Bohemian Rhapsody - 2011 Remaster — Queen ✓ IN PLAYLIST
# 30. Don't Know What You Got (Till It's Gone) — Cinderella
# 31. Breaking the Chains — Dokken
# 32. Fear Of The Dark - 1998 Remastered Version — Iron Maiden
# 33. Numb — Linkin Park
# 34. Going Under — Evanescence ✓ IN PLAYLIST
# 35. Metal Health (Bang Your Head) — Quiet Riot
# 36. Guilty All the Same (feat. Rakim) — Linkin Park
# 37. Lookin' at Me (feat. Puff Daddy) — Mase
# 38. Close My Eyes Forever — Lita Ford
# 39. Still Waiting — Sum 41 ✓ IN PLAYLIST
# 40. Victory (feat. The Notorious B.I.G. & Busta Rhymes) — Diddy
# 41. Uma Thurman — Fall Out Boy
# 42. I'm Shipping Up To Boston — Dropkick Murphys ✓ IN PLAYLIST
# 43. Hot For Teacher — Van Halen
# 44. Misery Business — Paramore
# 45. Just Like Paradise — David Lee Roth
# 46. Lifestyles of the Rich & Famous — Good Charlotte
# 47. Run to the Hills - 1998 Remastered Version — Iron Maiden
# 48. Wanted Dead Or Alive — Bon Jovi
# 49. The Final Countdown — Europe
# 50. What You Want — Evanescence
#
# --- Evaluation Results ---
# Songs in playlist (in dataset): 79
# Used as input: 10
# Held-out (ground truth): 67
# Recommendations generated: 50
# Hits (songs from playlist recommended): 14
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.2800
# Recall@50: 0.2090
#
# Hit songs (from original playlist):
#   - Rank 1: Guitar Man — Bread
#   - Rank 2: 21 Guns — Green Day
#   - Rank 4: So Far Away — Staind
#   - Rank 6: Lying from You — Linkin Park
#   - Rank 7: Prayer Of The Refugee — Rise Against
#   - Rank 12: One Last Breath — Creed
#   - Rank 13: Higher — Creed
#   - Rank 14: Breaking the Habit — Linkin Park
#   - Rank 16: Hero — Skillet
#   - Rank 21: Comatose — Skillet
#   - Rank 29: Bohemian Rhapsody - 2011 Remaster — Queen
#   - Rank 34: Going Under — Evanescence
#   - Rank 39: Still Waiting — Sum 41
#   - Rank 42: I'm Shipping Up To Boston — Dropkick Murphys
# Evaluating Pump Up the Jam
#
# ============================================================
# Evaluating Playlist: Pump Up the Jam
# ============================================================
# Total songs in playlist: 165
# Songs found in our dataset: 78/165
#
# --- Input Songs (randomly selected 10) ---
# 1. Come & Get It — Selena Gomez
# 2. All I Do Is Win - Feat. T-Pain, Ludacris, Snoop Dogg & Rick Ross — DJ Khaled
# 3. Lose Yourself - Soundtrack Version — Eminem
# 4. I Love It (feat. Charli XCX) - Original Version — Icona Pop
# 5. Here It Goes Again — OK Go
# 6. DJ Turn It Up — Yellow Claw
# 7. Clique — Kanye West
# 8. We Are One (Ole Ola) [The Official 2014 FIFA World Cup Song] — Pitbull
# 9. Call Me Maybe — Carly Rae Jepsen
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.5600
# Recall@50: 0.4242
#
# Hit songs (from original playlist):
#   - Rank 1: United We Dance - Radio Edit — Vicetone
#   - Rank 3: We Are The Ones - Radio Edit — twoloud
#   - Rank 5: Dear Boy - Avicii By Avicii — Avicii
#   - Rank 6: Gold Skies - Radio Edit — Sander van Doorn
#   - Rank 7: After Dark - Radio Edit — Style of Eye
#   - Rank 8: Together We Are (feat. Chris James) — ARTY
#   - Rank 9: Our Story - Radio Edit — Mako
#   - Rank 10: If It Wasn't For You — Alesso
#   - Rank 11: Leave The World Behind - Radio Edit — Axwell
#   - Rank 13: Lionhearted - Arty Remix — Porter Robinson
#   - Rank 14: Pick Up The Pieces - Radio Edit — Maor Levi
#   - Rank 15: Get Up - Original Mix — HIIO
#   - Rank 16: Bong — Deniz Koyu
#   - Rank 19: Pompeii - Audien Remix — Bastille
#   - Rank 24: We'll Be Ok — Afrojack
#   - Rank 25: Lies - Otto Knows Remix — BURNS
#   - Rank 28: Legacy - Radio Edit — Nicky Romero
#   - Rank 29: Peanut Butter Jelly — Galantis
#   - Rank 33: Dear Boy — Avicii
#   - Rank 34: You — Galantis
#   - Rank 35: Million Voices — Otto Knows
#   - Rank 36: Lost At Sea — Zedd
#   - Rank 39: Indigo — JDG
#   - Rank 42: Freedom — Afrojack
#   - Rank 44: We Were Gods (feat. Urban Cone & Lucas Nord) - Radio Edit — John Dahlbäck
#   - Rank 45: Keep Our Love Alive — Afrojack
#   - Rank 46: Illuminate — Afrojack
#   - Rank 47: Sunshine — David Guetta
# Evaluating Scelto dalla radio
#
# ============================================================
# Evaluating Playlist: Scelto dalla radio
# ============================================================
# Total songs in playlist: 136
# Songs found in our dataset: 73/136
#
# --- Input Songs (randomly selected 10) ---
# 1. A-Punk (Album) — Vampire Weekend
# 2. I Bet You Look Good On The Dancefloor — Arctic Monkeys
# 3. Midnight City — M83
# 4. Little Talks — Of Monsters and Men
# 5. Last Nite — The Strokes
# 6. Boys Don't Cry — The Cure
# 7. A-Punk — Vampire Weekend
# 8. Without Me — Eminem
# 9. Uprising — Muse
# 10. In Da Club — 50 Cent
#
# --- Recommendations (50 songs) ---
# 1. When The Sun Goes Down — Arctic Monkeys
# 2. She's Finding Me Out — The Friday Night Boys
# 3. Stupid Love Letter — The Friday Night Boys
# 4. Coffee — Sylvan Esso
# 5. White Sky — Vampire Weekend ✓ IN PLAYLIST
# 6. Feel Good Inc. — Gorillaz
# 7. I Want You — Kings of Leon
# 8. Sex on Fire — Kings of Leon
# 9. Last Nite — The Strokes
# 10. Fluorescent Adolescent — Arctic Monkeys
# 11. Freak Like Me — Halestorm
# 12. Fallen Leaves — Billy Talent
# 13. Out Of Control — Hoobastank
# 14. Electric Feel — MGMT
# 15. Pusherman — Curtis Mayfield
# 16. Scotty Doesn't Know — Lustra
# 17. Piledriver Waltz — Arctic Monkeys
# 18. Ready to Go - Remix — Ale Mendoza
# 19. Como Tu No Hay Dos — Buxxi ✓ IN PLAYLIST
# 20. Chelsea Dagger — The Fratellis ✓ IN PLAYLIST
# 21. I Miss the Misery — Halestorm
# 22. Wherever You Will Go — The Calling
# 23. Paper Trails — DARKSIDE
# 24. Outshined — Soundgarden
# 25. Use Somebody — Kings of Leon
# 26. Molly — Tyga
# 27. Under Cover of Darkness — The Strokes ✓ IN PLAYLIST
# 28. Hannah Hunt — Vampire Weekend
# 29. Daylight — Matt and Kim
# 30. Thnks fr th Mmrs — Fall Out Boy
# 31. Send the Pain Below — Chevelle
# 32. Booyah - Radio Edit — Showtek
# 33. 1985 — Bowling For Soup
# 34. Let's Get It Started — The Black Eyed Peas
# 35. Reptilia — The Strokes
# 36. Coming Back Again — Kings of Leon
# 37. Mr. Jones - Live At Chelsea Studios, New York/1997 — Counting Crows
# 38. Who The Fuck Are Arctic Monkeys? — Arctic Monkeys
# 39. Paris (Aeroplane Remix) — Friendly Fires
# 40. What the Hell — Avril Lavigne
# 41. Time to Pretend — MGMT ✓ IN PLAYLIST
# 42. Standing In The Way Of Control — Gossip
# 43. Somebody Told Me — The Killers
# 44. Welcome to My Life — Simple Plan
# 45. (I Can't Get No) Satisfaction - Mono Version — The Rolling Stones
# 46. Red Right Hand — Arctic Monkeys
# 47. Upside Down — Paloma Faith
# 48. Next Levels — King Geedorah
# 49. Gas Drawls — MF DOOM
# 50. We Won't Go Home — The Colourist
#
# --- Evaluation Results ---
# Songs in playlist (in dataset): 73
# Used as input: 10
# Held-out (ground truth): 62
# Recommendations generated: 50
# Hits (songs from playlist recommended): 5
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.1000
# Recall@50: 0.0806
#
# Hit songs (from original playlist):
#   - Rank 5: White Sky — Vampire Weekend
#   - Rank 19: Como Tu No Hay Dos — Buxxi
#   - Rank 20: Chelsea Dagger — The Fratellis
#   - Rank 27: Under Cover of Darkness — The Strokes
#   - Rank 41: Time to Pretend — MGMT
# Evaluating Soundtrack de vida
#
# ============================================================
# Evaluating Playlist: Soundtrack de vida
# ============================================================
# Total songs in playlist: 170
# Songs found in our dataset: 73/170
#
# --- Input Songs (randomly selected 10) ---
# 1. Can't Hold Us - feat. Ray Dalton — Macklemore & Ryan Lewis
# 2. All of Me — John Legend
# 3. Limbo — Daddy Yankee
# 4. Impossible — James Arthur
# 5. I Wanna Dance with Somebody (Who Loves Me) — Whitney Houston
# 6. Dancing On My Own — Robyn
# 7. Calling (Lose My Mind) - Radio Edit — Sebastian Ingrosso
# 8. Blurred Lines — Robin Thicke
# 9. Shower — Becky G
# 10. Animals — Martin Garrix
#
# --- Recommendations (50 songs) ---
# 1. Because Of You — Ne-Yo ✓ IN PLAYLIST
# 2. Loud — R5
# 3. Derp — Bassjackers
# 4. Old English — Young Thug
# 5. Break Free — Ariana Grande
# 6. I Am the Best (내가 제일 잘 나가) — 2NE1
# 7. Hella Hoes — A$AP Mob
# 8. Rollup - Baauer Remix — Flosstradamus
# 9. Jumper - Radio Edit — Hardwell
# 10. Salute — Little Mix
# 11. Go Get It — T.I.
# 12. Bang Bang — Jessie J
# 13. Booyah - Original Mix — Showtek
# 14. Can We Dance — The Vamps
# 15. Problem — Ariana Grande
# 16. Habits (Stay High) - The Chainsmokers Extended Mix — Tove Lo
# 17. Me And My Broken Heart — Rixton
# 18. She Wolf (Falling to Pieces) [feat. Sia] — David Guetta
# 19. Revolution — Diplo
# 20. La Venganza — J Balvin
# 21. She Don't Like The Lights - Acoustic Version — Justin Bieber
# 22. Summertime Sadness (Lana Del Rey Vs. Cedric Gervais) - Cedric Gervais Remix — Lana Del Rey
# 23. Una Vaina Loca — Fuego
# 24. Let Me Love You (Until You Learn To Love Yourself) — Ne-Yo
# 25. You - Tiësto vs. Twoloud Radio Edit — Galantis
# 26. Say My Name (feat. Zyra) - RAC Mix — ODESZA
# 27. Delirious (Boneless) (feat. Kid Ink) — Steve Aoki
# 28. Echa Pa'lla (Manos Pa'rriba) — Pitbull ✓ IN PLAYLIST
# 29. Sweet Nothing - Tiësto Remix — Calvin Harris
# 30. Nobody To Love - Radio Edit — Sigma
# 31. Dancing On My Own — Robyn
# 32. Love Me Again - Gemini Remix — John Newman ✓ IN PLAYLIST
# 33. Darte un Beso — Prince Royce ✓ IN PLAYLIST
# 34. I Wanna Feel - Radio Edit — Secondcity
# 35. Bailando - English Version — Enrique Iglesias
# 36. In My Head — Jason Derulo
# 37. Macarena — Los Del Rio
# 38. Vivir Mi Vida — Marc Anthony
# 39. Algo Me Gusta De Ti — Wisin & Yandel
# 40. Stay The Night - Featuring Hayley Williams Of Paramore — Zedd
# 41. Strangers — Seven Lions
# 42. Taboo — Don Omar
# 43. Destination - Michael Mind Remix Edit — Darius & Finlay
# 44. Animals — Maroon 5
# 45. Embrace — Goldroom
# 46. The Way I Are — Timbaland
# 47. Resurrection - Axwell's Recut Radio Edit — Michael Calfan
# 48. Señal de Vida - Radio Edit — Ñejo
# 49. Wing$ — Macklemore & Ryan Lewis
# 50. Voy a Beber — Nicky Jam
#
# --- Evaluation Results ---
# Songs in playlist (in dataset): 73
# Used as input: 10
# Held-out (ground truth): 63
# Recommendations generated: 50
# Hits (songs from playlist recommended): 4
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.0800
# Recall@50: 0.0635
#
# Hit songs (from original playlist):
#   - Rank 1: Because Of You — Ne-Yo
#   - Rank 28: Echa Pa'lla (Manos Pa'rriba) — Pitbull
#   - Rank 32: Love Me Again - Gemini Remix — John Newman
#   - Rank 33: Darte un Beso — Prince Royce
# Evaluating Childhood memories
#
# ============================================================
# Evaluating Playlist: Childhood memories
# ============================================================
# Total songs in playlist: 153
# Songs found in our dataset: 70/153
#
# --- Input Songs (randomly selected 10) ---
# 1. Creep — Radiohead
# 2. American Pie — Don McLean
# 3. Kryptonite — 3 Doors Down
# 4. In The End — Linkin Park
# 5. I'm Gonna Be (500 Miles) — The Proclaimers
# 6. Every Morning - Remastered — Sugar Ray
# 7. Crazy — Gnarls Barkley
# 8. One More Time — Daft Punk
# 9. Pieces Of Me — Ashlee Simpson
# 10. Thank You — Dido
#
# --- Recommendations (50 songs) ---
# 1. Return of the Mack — Mark Morrison
# 2. Lovefool — The Cardigans ✓ IN PLAYLIST
# 3. Drops of Jupiter — Train
# 4. Sweat (A La La La La Long) — Inner Circle ✓ IN PLAYLIST
# 5. White Flag — Dido ✓ IN PLAYLIST
# 6. Inevitable - En Vivo — Shakira
# 7. Kryptonite — 3 Doors Down
# 8. La Flaca - Acousique — Jarabe De Palo
# 9. Vuelve - MTV Unplugged Version — Ricky Martin
# 10. The Walk — Mayer Hawthorne
# 11. No Woman, No Cry - Live At The Lyceum, London/1975 — Bob Marley & The Wailers ✓ IN PLAYLIST
# 12. Hysteria — Def Leppard ✓ IN PLAYLIST
# 13. 1973 - Acoustic — James Blunt
# 14. Fireflies - Live From Spotify NYC — Owl City
# 15. Nada Valgo Sin Tu Amor - MTV Unplugged — Juanes
# 16. Mamita (feat. Natalia Lafourcade) — Rawayana
# 17. Alone Again (Naturally) — Gilbert O'Sullivan ✓ IN PLAYLIST
# 18. The Way — Fastball
# 19. Animal Instinct — The Cranberries ✓ IN PLAYLIST
# 20. You Get What You Give — New Radicals ✓ IN PLAYLIST
# 21. Have You Ever Seen The Rain? — Creedence Clearwater Revival
# 22. My Favourite Game — The Cardigans ✓ IN PLAYLIST
# 23. Don't You Want Me — Bahamas
# 24. Ironic - Acoustic — Alanis Morissette
# 25. It Wasn't Me — Shaggy ✓ IN PLAYLIST
# 26. Imagine — Jack Johnson
# 27. It's Oh So Quiet — Björk ✓ IN PLAYLIST
# 28. Stand Up — Jessie J
# 29. You Were Meant For Me — Jewel
# 30. The Reason — Hoobastank ✓ IN PLAYLIST
# 31. If You Leave Me Now — Chicago ✓ IN PLAYLIST
# 32. Demons - Live London Sessions / 2013 — Imagine Dragons
# 33. Banana Pancakes — Jack Johnson
# 34. Hold the Line — TOTO
# 35. Complicated — Avril Lavigne ✓ IN PLAYLIST
# 36. Mr. Jones - Live At Chelsea Studios, New York/1997 — Counting Crows
# 37. Bashment — Ape Drums
# 38. Billie Jean — Michael Jackson
# 39. Burn - Confession Special Edition Version — Usher
# 40. Dammit — blink-182
# 41. Who's Laughing Now — Jessie J
# 42. South of the Border (feat. Camila Cabello & Cardi B) - Andy Jarvis Remix — Ed Sheeran
# 43. Crack A Bottle — Eminem
# 44. Glam - Electro-swing Remix — Dimie Cat
# 45. Better Together — Jack Johnson
# 46. Make It with You — Bread
# 47. Are You Satisfied? — Reignwolf
# 48. Geraldines Routine — Tape Five
# 49. Canela en Rama — El Kanka
# 50. More Than Words — Extreme
#
# --- Evaluation Results ---
# Songs in playlist (in dataset): 70
# Used as input: 10
# Held-out (ground truth): 60
# Recommendations generated: 50
# Hits (songs from playlist recommended): 14
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.2800
# Recall@50: 0.2333
#
# Hit songs (from original playlist):
#   - Rank 2: Lovefool — The Cardigans
#   - Rank 4: Sweat (A La La La La Long) — Inner Circle
#   - Rank 5: White Flag — Dido
#   - Rank 11: No Woman, No Cry - Live At The Lyceum, London/1975 — Bob Marley & The Wailers
#   - Rank 12: Hysteria — Def Leppard
#   - Rank 17: Alone Again (Naturally) — Gilbert O'Sullivan
#   - Rank 19: Animal Instinct — The Cranberries
#   - Rank 20: You Get What You Give — New Radicals
#   - Rank 22: My Favourite Game — The Cardigans
#   - Rank 25: It Wasn't Me — Shaggy
#   - Rank 27: It's Oh So Quiet — Björk
#   - Rank 30: The Reason — Hoobastank
#   - Rank 31: If You Leave Me Now — Chicago
#   - Rank 35: Complicated — Avril Lavigne
# Evaluating Norris
#
# ============================================================
# Evaluating Playlist: Norris
# ============================================================
# Total songs in playlist: 137
# Songs found in our dataset: 69/137
#
# --- Input Songs (randomly selected 10) ---
# 1. Crazy — Gnarls Barkley
# 2. Ante Up (Robbin Hoodz Theory) — M.O.P.
# 3. Lean Back — Terror Squad
# 4. In Da Club — 50 Cent
# 5. Holocene — Bon Iver
# 6. Dancing On My Own — Robyn
# 7. Rolling in the Deep — Adele
# 8. Best I Ever Had — Drake
# 9. Paper Planes — M.I.A.
# 10. Use Somebody — Kings Of Leon
#
# --- Recommendations (50 songs) ---
# 1. Won't Trade — Q-Tip
# 2. Slipping Away (Crier la Vie) [Radio Mix] — Moby
# 3. Umbrella — Rihanna
# 4. Ridin' the Storm Out — REO Speedwagon
# 5. TTYLXOX — Bella Thorne
# 6. Part II — Method Man
# 7. Lean Back — Terror Squad
# 8. Mojo So Dope — Kid Cudi
# 9. A Milli — Lil Wayne
# 10. I Wanna Love You — Akon
# 11. 1 Thing — Amerie ✓ IN PLAYLIST
# 12. Clean up Woman — Betty Wright
# 13. Initiated (feat. 2Pac a.k.a. Makaveli, Outlawz & Kurupt Tha Kingpin) — Daz Dillinger
# 14. Beautiful — Snoop Dogg
# 15. Stutter (feat. Mystikal) - Double Take Remix — Joe ✓ IN PLAYLIST
# 16. Smoke Two Joints — Sublime
# 17. This D.J. — Warren G
# 18. Two Dope Boyz (In a Cadillac) — OutKast
# 19. Let Me Love You — Mario
# 20. Single Ladies (Put a Ring On It) — The Cleverlys
# 21. Get Ur Freak On — Missy Elliott ✓ IN PLAYLIST
# 22. Country Grammar (Hot Shit) — Nelly
# 23. Drop It Like It's Hot — Snoop Dogg
# 24. Jesus Walks — Kanye West ✓ IN PLAYLIST
# 25. Make Me Better — Fabolous
# 26. Gravel Pit — Wu-Tang Clan
# 27. Walk It Out — Unk
# 28. Bandz A Make Her Dance (feat. Lil' Wayne & 2 Chainz) — Juicy J
# 29. Bongo Bong — Manu Chao
# 30. No More (Cuban Linx 2000) (feat. Ghostface Killah & Raekwon) — Ruff Endz
# 31. Hey Mr. D.J. — Zhané
# 32. Da Rockwilder — Method Man
# 33. Warm on a Cold Night — HONNE
# 34. Stay Fly (feat. Young Buck, Eightball & MJG) - Explicit Album Version — Three 6 Mafia
# 35. Rapp Snitch Knishes feat. Mr. Fantastik — MF DOOM
# 36. Who Ride Wit Us — Kurupt
# 37. How Deep Is Your Love - Single Version — Dru Hill
# 38. Candy Girl — New Edition
# 39. The Book of Love — The Magnetic Fields
# 40. Fast Lane — Bad Meets Evil
# 41. Tell Me — Groove Theory
# 42. Me, Myself and I — Beyoncé
# 43. Ya Mama — The Pharcyde
# 44. It's Love — Jill Scott
# 45. 2 On — Tinashe
# 46. Complicated — Avril Lavigne ✓ IN PLAYLIST
# 47. Ignition - Remix — R. Kelly
# 48. Next Levels — King Geedorah
# 49. Nakamarra (feat. Q-Tip) — Hiatus Kaiyote
# 50. Gas Drawls — MF DOOM
#
# --- Evaluation Results ---
# Songs in playlist (in dataset): 69
# Used as input: 10
# Held-out (ground truth): 59
# Recommendations generated: 50
# Hits (songs from playlist recommended): 5
# Hit Rate (at least 1 hit): 1
# Precision@50: 0.1000
# Recall@50: 0.0847
#
# Hit songs (from original playlist):
#   - Rank 11: 1 Thing — Amerie
#   - Rank 15: Stutter (feat. Mystikal) - Double Take Remix — Joe
#   - Rank 21: Get Ur Freak On — Missy Elliott
#   - Rank 24: Jesus Walks — Kanye West
#   - Rank 46: Complicated — Avril Lavigne
# Mean precision: 0.30399999999999994

# %% [markdown]
# CBF model

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

print('Loading features from spotify_df_cleaned.csv...')

# Load the cleaned Spotify data with all features
spotify_df = pd.read_csv('data/spotify_df_cleaned.csv', encoding='utf-8', encoding_errors='ignore')
print(f'Loaded {len(spotify_df)} songs with features')
print(f'Available columns: {spotify_df.columns.tolist()}')

# Define all available features (audio + metadata)
numeric_features = [
    'track_popularity',  # Popularity signal!
    'danceability', 'energy', 'key', 'loudness', 'mode',
    'speechiness', 'acousticness', 'instrumentalness',
    'liveness', 'valence', 'tempo', 'duration_ms', 'release_year'
]

categorical_features = [
    'playlist_genre', 'playlist_subgenre'
]

# Extract numeric features
numeric_data = spotify_df[numeric_features].copy()
print(f'\nUsing {len(numeric_features)} numeric features: {numeric_features}')

# Handle NaN values in numeric features
nan_count = numeric_data.isna().sum().sum()
if nan_count > 0:
    print(f'Filling {nan_count} NaN values in numeric features...')
    numeric_data = numeric_data.fillna(numeric_data.mean())

# Encode categorical features
encoded_features = []
for cat_col in categorical_features:
    if cat_col in spotify_df.columns:
        print(f'Encoding {cat_col}...')
        le = LabelEncoder()
        encoded = le.fit_transform(spotify_df[cat_col].fillna('unknown'))
        encoded_features.append(encoded.reshape(-1, 1))

# Combine all features
if encoded_features:
    categorical_array = np.hstack(encoded_features)
    feature_matrix = np.hstack([numeric_data.values, categorical_array])
    print(f'Combined features: {numeric_data.shape[1]} numeric + {categorical_array.shape[1]} categorical')
else:
    feature_matrix = numeric_data.values
    print(f'Using only numeric features')

# Note: Numeric features are already standardized in spotify_df_cleaned.csv
# Only standardize the categorical features to match the scale
if encoded_features:
    print('Standardizing categorical features to match pre-scaled numeric features...')
    scaler = StandardScaler()
    categorical_scaled = scaler.fit_transform(categorical_array)
    feature_matrix = np.hstack([numeric_data.values, categorical_scaled])

print(f'Final feature matrix shape: {feature_matrix.shape}')
# Out:
# Loading features from spotify_df_cleaned.csv...
# Loaded 32828 songs with features
# Available columns: ['track_id', 'track_popularity', 'track_album_release_date', 'playlist_name', 'playlist_genre', 'playlist_subgenre', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'release_year']
#
# Using 14 numeric features: ['track_popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'release_year']
# Filling 1886 NaN values in numeric features...
# Encoding playlist_genre...
# Encoding playlist_subgenre...
# Combined features: 14 numeric + 2 categorical
# Final feature matrix shape: (32828, 16)

# %%
# CBF Recommendation Function
def recommend_cbf(seed_song_tuples, n_recs=50):
    """Content-based filtering using audio features"""
    seed_idxs = []
    for title, artist in seed_song_tuples:
        key = (normalize_text(title), normalize_text(artist))
        idx = rec_lookup.get(key)
        if idx is not None:
            seed_idxs.append(idx)
    
    if not seed_idxs:
        return 'No valid seeds found in recommendation dataset'
    
    # Average the feature vectors of seed songs
    seed_features = feature_matrix[seed_idxs].mean(axis=0).reshape(1, -1)
    
    # Compute cosine similarity to all songs
    similarities = cosine_similarity(seed_features, feature_matrix).flatten()
    
    # Get top recommendations excluding seeds
    ranking = np.argsort(-similarities)
    recs = [idx for idx in ranking if idx not in seed_idxs][:n_recs]
    
    return recommendationInfo_df.iloc[recs].reset_index(drop=True)

# %% [markdown]
# Hybrid Model: Combine both CF and CBF approaches with weighted averaging

# %%
# Hybrid Recommendation Function (CF + CBF)
def recommend_hybrid(seed_song_tuples, n_recs=50, cf_weight=0.85, cbf_weight=0.15):
    """Hybrid: combines collaborative and content-based filtering"""
    # Get seed indices
    seed_idxs = []
    for title, artist in seed_song_tuples:
        key = (normalize_text(title), normalize_text(artist))
        idx = rec_lookup.get(key)
        if idx is not None:
            seed_idxs.append(idx)
    
    if not seed_idxs:
        return 'No valid seeds found in recommendation dataset'
    
    # Get CF similarities, SVD item factors
    cf_query = item_factors[seed_idxs].mean(axis=0).reshape(1,-1)
    cf_sims = cosine_similarity(cf_query, item_factors).flatten()
    
    # Get CBF similarities, from audio features
    cbf_query = feature_matrix[seed_idxs].mean(axis=0).reshape(1, -1)
    cbf_sims = cosine_similarity(cbf_query, feature_matrix).flatten()
    
    # Normalize
    cf_sims_norm = (cf_sims - cf_sims.min()) / (cf_sims.max() - cf_sims.min() + 1e-10)
    cbf_sims_norm = (cbf_sims - cbf_sims.min()) / (cbf_sims.max() - cbf_sims.min() + 1e-10)
    
    # Weighted combination
    hybrid_scores = (cf_weight * cf_sims_norm) + (cbf_weight * cbf_sims_norm)
    
    # top recommendations
    ranking = np.argsort(-hybrid_scores)
    recs = [idx for idx in ranking if idx not in seed_idxs][:n_recs]
    
    return recommendationInfo_df.iloc[recs].reset_index(drop=True)

# %% [markdown]
# Model Comparison: CF, CBF, and Hybrid

# %%
# Unified evaluation function for any model
def evaluate_model(recommend_func, playlist_name, n_seed=10, n_recs=50, model_name="Model"):
    """Evaluate any recommendation model (CF, CBF, or Hybrid)"""
    playlist_songs = playlists_df[playlists_df['playlistname'] == playlist_name].copy()
    
    if len(playlist_songs) == 0:
        return None
    
    matched_songs = []
    for idx, row in playlist_songs.iterrows():
        if pd.notna(row.get('dataset_idx')):
            matched_songs.append({
                'track': row['trackname'],
                'artist': row['artistname'],
                'dataset_idx': int(row['dataset_idx'])
            })
    
    if len(matched_songs) < n_seed:
        return None
    
    # Split into seed and holdout
    random.seed(42)
    seed_songs = random.sample(matched_songs, n_seed)
    remaining_songs = [s for s in matched_songs if s not in seed_songs]
    
    # Get recommendations using specified model
    seed_list = [(s['track'], s['artist']) for s in seed_songs]
    recs_df = recommend_func(seed_list, n_recs=n_recs)
    
    if isinstance(recs_df, str):
        return None
    
    # Calculate metrics
    remaining_indices = {s['dataset_idx'] for s in remaining_songs}
    hits = 0
    for i in range(len(recs_df)):
        track = recs_df.iloc[i]['track_name']
        artist = recs_df.iloc[i]['track_artist']
        
        # Find the index in recommendationInfo_df
        mask = (
            recommendationInfo_df["track_name"].str.lower().str.strip() == track.lower().strip()
        ) & (
            recommendationInfo_df["track_artist"].str.lower().str.strip() == artist.lower().strip()
        )
        
        if mask.sum() > 0:
            rec_idx = recommendationInfo_df[mask].index[0]
            if rec_idx in remaining_indices:
                hits += 1
    
    precision = hits / n_recs if n_recs > 0 else 0
    recall = hits / len(remaining_songs) if len(remaining_songs) > 0 else 0
    hit_rate = 1 if hits > 0 else 0
    
    return {
        'model': model_name,
        'playlist': playlist_name,
        'precision': precision,
        'recall': recall,
        'hit_rate': hit_rate,
        'hits': hits,
        'total_holdout': len(remaining_songs)
    }

# %%
# Compare CBF, CF, and Hybrid models on chosen playlists
def compare_models(playlist_names, n_seed=10, n_recs=50):
    results = []
    
    for name in playlist_names:
        print(f'Evaluating {name}...')
        
        # CF
        res_cf = evaluate_model(recommend_collaborative, name, n_seed, n_recs, "CF")
        if res_cf: 
            results.append(res_cf)
            print(f"  CF: Precision={res_cf['precision']:.4f}")
        
        # CBF
        res_cbf = evaluate_model(recommend_cbf, name, n_seed, n_recs, "CBF")
        if res_cbf: 
            results.append(res_cbf)
            print(f"  CBF: Precision={res_cbf['precision']:.4f}")
        
        # Hybrid
        res_hybrid = evaluate_model(recommend_hybrid, name, n_seed, n_recs, "Hybrid")
        if res_hybrid: 
            results.append(res_hybrid)
            print(f"  Hybrid: Precision={res_hybrid['precision']:.4f}")
        
        print()
    
    # results
    df_results = pd.DataFrame(results)
    
    print("\n" + "="*70)
    print("MODEL COMPARISON SUMMARY")
    print("="*70)
    
    summary = df_results.groupby('model').agg({
        'precision': ['mean', 'std', 'min', 'max'],
        'recall': ['mean', 'std'],
        'hit_rate': 'mean'
    }).round(4)
    
    print(summary)
    
    best_model = df_results.groupby('model')['precision'].mean().idxmax()
    best_precision = df_results.groupby('model')['precision'].mean().max()
    print(f"\n Best Model: {best_model} (Mean Precision: {best_precision:.4f})")
    
    return df_results

print("Comparing models on 5 playlists...\n")
comparison_results = compare_models(chosen[:5], n_seed=10, n_recs=50)
# Out:
# Comparing models on 5 playlists...
#
# Evaluating Birgit Party...
#   CF: Precision=0.3200
#   CBF: Precision=0.0000
#   Hybrid: Precision=0.3600
#
# Evaluating ZLX...
#   CF: Precision=0.2800
#   CBF: Precision=0.0000
#   Hybrid: Precision=0.3800
#
# Evaluating 80's (full)...
#   CF: Precision=0.5800
#   CBF: Precision=0.0000
#   Hybrid: Precision=0.6200
#
# Evaluating Afternoon Delight...
#   CF: Precision=0.4000
#   CBF: Precision=0.0000
#   Hybrid: Precision=0.4000
#
# Evaluating hippity hoppity...
#   CF: Precision=0.3600
#   CBF: Precision=0.0600
#   Hybrid: Precision=0.3600
#
#
# ======================================================================
# MODEL COMPARISON SUMMARY
# ======================================================================
#        precision                      recall         hit_rate
#             mean     std   min   max    mean     std     mean
# model
# CBF        0.012  0.0268  0.00  0.06  0.0067  0.0149      0.2
# CF         0.388  0.1163  0.28  0.58  0.1763  0.0661      1.0
# Hybrid     0.424  0.1108  0.36  0.62  0.1909  0.0615      1.0
#
#  Best Model: Hybrid (Mean Precision: 0.4240)
